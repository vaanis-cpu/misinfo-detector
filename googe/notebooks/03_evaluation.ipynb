# %% [markdown]
# # 03 - Evaluation
#
# This notebook evaluates model performance on held-out test data.

# %%
import sys
sys.path.insert(0, '..')

import numpy as np
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
from src.models.scoring import RiskCalculator
from src.models.gnn import GraphSAGEModel
from src.types import GraphSnapshot

# %%
# Sample evaluation metrics
# In production, this would use a proper train/test split

y_true = [0, 1, 1, 0, 1, 0, 1, 0, 0, 1]  # Ground truth labels
y_pred = [0, 1, 0, 0, 1, 0, 1, 1, 0, 1]  # Predicted labels

accuracy = accuracy_score(y_true, y_pred)
precision, recall, f1, _ = precision_recall_fscore_support(y_true, y_pred, average='binary')

print(f"Accuracy:  {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall:    {recall:.4f}")
print(f"F1 Score:  {f1:.4f}")

# %%
# Note: Full evaluation requires:
# 1. Held-out test set from real datasets
# 2. Benchmarking against existing tools (ClaimBuster, Snopes)
# 3. Temporal evaluation (does prediction improve over time?)

print("For full evaluation, see scripts/evaluate_model.py")
